# %% [markdown]
# <a href="https://colab.research.google.com/github/suryadi14072003-del/PEMEROGRAMAN-DASAR/blob/main/Pertemuan_1_Malam_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biodata Saya

nama = "Suryadi"
umur = 23
jurusan = "Elektro"
prodi = "RPE"
semester = 3
matakuliah = 'Pemerograman Dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (prodi)
print (semester)
print (matakuliah)
print(status_lulus)
# Out:
# Suryadi
# 23
# Elektro
# RPE
# 3
# Pemerograman Dasar
# False
