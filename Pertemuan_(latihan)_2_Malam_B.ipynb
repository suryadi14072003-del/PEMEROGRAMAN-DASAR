# %% [markdown]
# <a href="https://colab.research.google.com/github/suryadi14072003-del/PEMEROGRAMAN-DASAR/blob/main/Pertemuan_(latihan)_2_Malam_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # jawaban latihan 1
# # data sebuah panel surya
# tegangan = 18
# arus = 6
# jenis_sel = "Monocrystalline"
# print(tegangan, arus, jenis_sel)
#
# # jawaban latihan 2
# hambatan = 0.5
# arus = 5
# label = "resistor"
# ohm = True
#
# print(type(hambatan))
# print(type(arus))
# print(type(label))
# print(type(ohm))
#
#
# 18 6 Monocrystalline
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>
#
# # jawaban latihan 3
# nama_unit = "PLTS Nunukan"
# jumlah_panel = 240
# tegangan_keluaran = 48.5
# sedang_beroperasi = True
#
# print(nama_unit,type(nama_unit))
# print(jumlah_panel,type(jumlah_panel))
# print(tegangan_keluaran,type(tegangan_keluaran))
# print(sedang_beroperasi,type(sedang_beroperasi))
#
#
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>
#
# # jawaban latihan 4
# # pembacaan pertama dan terakhir memakai indeks
# tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]
# print(tegangan_harian[0], tegangan_harian[5])
#
# # tambahkan satu pembacaan baru 220.0 dengan append()
# tegangan_harian.append(220.0)
# print(tegangan_harian)
#
# # cetak jumlah total data dengan len()
# tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 222.0]
# print(len(tegangan_harian))
#
# 217.5 216.9
# [217.5, 219.0, 220.3, 218.7, 221.1, 216.9, 220.0]
# 7
#
# # jawaban latihan 5
# motor = {
#     "nama": "motor_listrik",
#     "daya_kW": 100,
#     "tegangan_V": 11,
#     "rpm" : 1450
# }
# print("daya:", motor["daya_kW"], "kW")
#
# # ubah nilai rpm pakai =
# motor["rpm"] = 1500
#
# print(motor)
#
# daya: 100 kW
# {'nama': 'motor_listrik', 'daya_kW': 100, 'tegangan_V': 11, 'rpm': 1500}
#
# # jawaban latihan 6
# pembangkit = [
#     {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
#     {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
#     {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
# ]
# print(pembangkit[1])
#
# # ubah status salah satu unit
# pembangkit[1]["status"] = "pemeliharaan"
# print(pembangkit[1])
#
# # tambahkan 1 unit baru dengan append()
# pembangkit.append({"nama": "Unit-4", "kapasitas_MW" : 120, "status": "operasi"})
# print(pembangkit)
#
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'pemeliharaan'}
# [{'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}, {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'pemeliharaan'}, {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'pemeliharaan'}, {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}]
